# %% [markdown]
# <a href="https://colab.research.google.com/github/mandafifah04/PCVK_Semeter6/blob/main/Week2_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# Accessing My Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
#import matplotlib
import matplotlib.pyplot as plt
import numpy as np
#membaca gambar yang conect ke google drive
img = cv.imread('/content/drive/MyDrive/PCVK_MM/kitten02.jpg')
plt.imshow(img)

# %%
img2 = img
#menganti variable dengan img3 kemudian akan
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
plt.imshow(img3)

# %%
#ini memberi nama variable img_gray 
img_gray = cv.imread('/content/drive/MyDrive/PCVK_MM/kitten02.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
# rgb di resize dalam ukuran panjang 512 dan lebar 1024
img4 = cv.resize(cv.cvtColor(img, cv.COLOR_BGR2RGB), (512, 1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img, cv.COLOR_BGR2RGB), 0)#vertikal 

#simpan file image
#cv.imwrite('/content/drive/MyDrive/PCVK_MM/kitten02.jpg', img5)

#tampilkan plot dengan ukuran canvas yang lebih besar
fig = plt.figure(figsize=(5, 5))    # ubah-ubah ukuran (10,10) sesuai kebutuhan diubah gambarnya akan mengecil 
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)# zeros membuat kotak
#3,4,5 angka --> membuat gambar 
plt.imshow(black_img)

# %%
#perhatikan koordinat titik2 pt1 dan pt2
cv.rectangle(black_img,pt1=(382,0),pt2=(510,150),color=(0,255,0),thickness=10)#bigin ratagel --> di ganti 
#382 = vertikal lebar  0 (tinggi) ,510 lebar ,150 tinggi 
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=5)# thicnkness ketebalan -->-1 memenuhi 
plt.imshow(black_img)# 200 lebar,200 tinngi

# %%
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)#mencari titik tengah radius (jari-jari) 50

# %%
cv.circle(black_img,center=(400,400),radius=50,color=(255,0,0),thickness=-1)
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)#lebar 
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)#10 lebar tinggi 500 
plt.imshow(black_img)

# %%
black_img2=np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100, 300], [200, 200], [400, 300], [200, 400]], dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1, 1, 2)) #vertices = titik resep => di rubah bentuknaya
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2, [pts], isClosed=True, color=(255, 0, 0), thickness=5)
plt.imshow(black_img2)#pts memangil array klo true

# %% [markdown]
# Pertanyaan
# 1.	Apakah perbedaan gambar yang ditampilkan tanpa dan dengan matplotlib?
#
# Jawab :
# Ketika menggunakan matplotlib gambar ditampilkan dengan ukuran di samping dan bawah sehingga koordinat gambar dapat ditentukan.
#
# 2.	Apakah perbedaan dan pengaruhnya pembuatan black image antara tipe data int16  dan int32?
#
# Jawab :
# Perbedaannya terletak pada jumlah bit. dengan ukuran bit yang berbeda akan berpengaruh pada ukuran file gambar, semakin besar jumlah bit maka semakin besar ukuran file gambar.
#
# 3.	Apakah kegunaan “google.colab.patches import cv2_imshow” pada potongan kode  berikut
#
#
# Jawab :
# Kode tersebut merupakan library python yang digunakan untuk menampilkan gambar di google colab
#
# 4.	Apakah kegunaan “skimage import io” pada potongan kode soal nomor 3
#
# Jawab :
# Skimage import io adalah library yang digunakan untuk memproses gambar.

# %% [markdown]
# Tugas

# %% [markdown]
# 1.	Dengan menggunakan figsize, perhatikan apakah ukuran image pixelnya juga berubah?
#
# Jawab :
# Dengan menggunakan figsize ukuran pixel image tidak berubah.

# %%
#membaca gambar yang conect ke google drive
imgini = cv.imread('/content/drive/MyDrive/PCVK_MM/kitten.jpeg')
plt.imshow(imgini)

# %%
imgini2 = imgini
#menganti variable dengan img3 kemudian akan di tampilkan img3
imgini3 = cv.cvtColor(imgini,cv.COLOR_BGR2RGB)#covrensi 
plt.imshow(imgini3)

# %%
imgini2 = imgini
#menganti variable dengan img3 kemudian akan di tampilkan img3
imgini3 = cv.cvtColor(imgini,cv.COLOR_BGR2RGB) #tidak sesuai mata kita --> maka yang tidak sesui imread => klo baca open cv di buat dengan cllor 
cv2_imshow(imgini3)
# Out:
# <PIL.Image.Image image mode=RGB size=237x213 at 0x7F153FEAE910>

# %%
imgku = cv.imread('/content/drive/MyDrive/PCVK_MM/kitten.jpeg')
plt.imshow(imgku)

# %%
#2 Tampilkan image dalam channel Red-Blue dan Green-Blue saja!
# Load gambar
img = cv.imread('/content/drive/MyDrive/PCVK_MM/kitten.jpeg')
# Konversi gambar dari BGR ke RGB
img2 = cv.cvtColor(img, cv.COLOR_BGR2RGB)
# Buat variable RGB untuk dilakukan split warna pada gambar
R,G,B = cv.split(img2)
# Method zeros digunakan untuk membuat array kosong
zeros = np.zeros(img2.shape[:2], dtype="uint8")
# Tampilkan warna merah hijau
red_blue = cv.merge([R,zeros,B])
plt.imshow(red_blue)

# %%
img = cv.imread('/content/drive/MyDrive/PCVK_MM/kitten.jpeg')
# Konversi gambar dari BGR ke RGB
img2 = cv.cvtColor(img, cv.COLOR_BGR2RGB)
b = img[:,:,0]
g = img[:,:,1]
r = img[:,:,2]

divb = np.split(b,8)  # divide b in submatrices 8x8?
divg = np.split(g,8)  # divide g in submatrices 8x8?
divr = np.split(r,8)  # divide r in submatrices 8x8?
print('blue:', b)
print('red:', g)
print('green:', r)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-3251ea37dcb8> in <module>
#       6 r = img[:,:,2]
#       7
# ----> 8 divb = np.split(b,8)  # divide b in submatrices 8x8?
#       9 divg = np.split(g,8)  # divide g in submatrices 8x8?
#      10 divr = np.split(r,8)  # divide r in submatrices 8x8?
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/overrides.py in split(*args, **kwargs)
#
# /usr/local/lib/python3.8/dist-packages/numpy/lib/shape_base.py in split(ary, indices_or_sections, axis)
#     870         N = ary.shape[axis]
#     871         if N % sections:
# --> 872             raise ValueError(
#     873                 'array split does not result in an equal division') from None
#     874     return array_split(ary, indices_or_sections, axis)
#
# ValueError: array split does not result in an equal division

# %%
# 2.Tampilkan image dalam channel Red-Blue dan Green-Blue saja!

#Red-Blue
plt.imshow(img_gray, cmap='RdBu')

# %%
#Green-Blue
plt.imshow(img_gray, cmap='GnBu')#reeed pakak open cv reaad show pakek cv

# %%
# 3.	Tampilkan image baris ke 20-115, kolom 25-120!

plt.imshow(img3[20:115, 25:120])

# %%
# 4.	Tampilkan image baris ke 5-30, semua kolom, channel Red saja!

plt.imshow(img_gray[5:30], cmap="Reds")

# %%
# 5.	Buat 5 kotak berbagai ukuran dan warna yang berbeda dalam satu image. disarankan menggunakan bilangan acak/random!

img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)

cv.rectangle(img5,pt1=(30,30),pt2=(100,100),color=(255,0,255),thickness=5)
cv.rectangle(img5,pt1=(100,100),pt2=(200,200),color=(0,255,0),thickness=5)
cv.rectangle(img5,pt1=(200,200),pt2=(250,250),color=(255,0,187),thickness=5)
cv.rectangle(img5,pt1=(250,250),pt2=(300,300),color=(255,156,255),thickness=5)
cv.rectangle(img5,pt1=(300,300),pt2=(350,350),color=(0,0,0),thickness=5)


plt.imshow(img5)

# %%
# 6.	Tampilkan image dengan posisi terbalik!

img5 = cv.flip(cv.cvtColor(img, cv.COLOR_BGR2RGB), 0)

#simpan file image
#cv.imwrite('/content/drive/MyDrive/PCVK_MM/kitten02.jpg', img5)

#tampilkan plot dengan ukuran canvas yang lebih besar
fig = plt.figure(figsize=(10, 10))    # ubah-ubah ukuran (10,10) sesuai kebutuhan
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
# 7.	Buat rectangle dan circle pada bagian wajah dari image foto anda saat beraktifitas (bukan pasfoto).

my_photo = cv.imread('/content/drive/MyDrive/PCVK_MM/kitten02.jpg')

my_photo = cv.cvtColor(my_photo, cv.COLOR_BGR2RGB)

cv.rectangle(my_photo, pt1=(400, 530), pt2=(630, 760), color=(255, 0, 0), thickness=10)

cv.circle(my_photo, center=(510, 650), radius=130, color=(0, 255, 0), thickness=8)

plt.imshow(my_photo)

# %%
# 8.	Buat rectangle pada bagian sudut bawah kiri channel B pada color space RGB dari citra kitten/ lena/ mandrill/ male/ female/ couple/ sailboat/ peppers! 

kitten = cv.imread('/content/drive/MyDrive/PCVK_MM/kitten02.jpg')

kitten_rgb = cv.cvtColor(kitten, cv.COLOR_BGR2RGB)

cv.rectangle(kitten_rgb, pt1=(0, 350), pt2=(150, 500), color=(0, 0, 0), thickness=5)

plt.imshow(kitten_rgb)

# %%
#9.	Lengkapi tulisan nama file pada file citra dari soal no.8. gunakan font, ukuran font, dan warna font yang sesuai keinginan anda.

font = cv.FONT_ITALIC
cv.putText(kitten_rgb, text="kitten01.jpg", org=(200, 400), fontFace=font, fontScale=2, color=(0, 0, 0), thickness=3, lineType=cv.LINE_AA)
plt.imshow(kitten_rgb)
